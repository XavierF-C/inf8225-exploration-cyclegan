# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2447, done.
# remote: Total 2447 (delta 0), reused 0 (delta 0), pack-reused 2447
# Receiving objects: 100% (2447/2447), 8.18 MiB | 34.89 MiB/s, done.
# Resolving deltas: 100% (1535/1535), done.

# %%
import os
os.chdir('/content/pytorch-CycleGAN-and-pix2pix/')

# %%
os.getcwd()
# Out:
# '/content/pytorch-CycleGAN-and-pix2pix'

# %%
# !pip install -r requirements.txt
# !pip install -q kaggle
# Out:
# ...
#      |████████████████████████████████| 676 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 61.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 62.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 66.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=60bd76457921a1f1c7250f15668dad8bce9ee026a29edf021013e0ca62d0007c
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=cb47dd5b36643c0aebba4676a3fabfd0b09d898f5d35d0a04a5f2bc909d3760b
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# ...

# %%
# !gdown https://drive.google.com/file/d/1WdIXuBDVhhCNxKhne6JDgx4IX-0203pA/view?usp=sharing
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/parse_url.py:39: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1WdIXuBDVhhCNxKhne6JDgx4IX-0203pA
#   url="https://drive.google.com/uc?id={}".format(file_id)
# Downloading...
# From: https://drive.google.com/file/d/1WdIXuBDVhhCNxKhne6JDgx4IX-0203pA/view?usp=sharing
# To: /content/pytorch-CycleGAN-and-pix2pix/view?usp=sharing
# 68.6kB [00:00, 2.87MB/s]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-94dcaa3a-0748-442f-9410-215b9549f0e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94dcaa3a-0748-442f-9410-215b9549f0e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sketch-rendered.zip to sketch-rendered.zip

# %%
# !unzip sketch-rendered.zip  -d /content/pytorch-CycleGAN-and-pix2pix/datasets/sketch-data

# %%
# !mkdir ~/.kaggle

# %%
! cp /content/kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tongpython/cat-and-dog
# Out:
# ...
#  96% 209M/218M [00:01<00:00, 103MB/s]
# 100% 218M/218M [00:01<00:00, 127MB/s]

# %%
# !kaggle datasets download -d ipythonx/van-gogh-paintings
# Out:
# ...
#  96% 465M/485M [00:03<00:00, 162MB/s]
# 100% 485M/485M [00:03<00:00, 140MB/s]

# %%
# !kaggle datasets download -d dansbecker/food-101
# Out:
# ...
# 100% 9.37G/9.38G [01:13<00:00, 151MB/s]
# 100% 9.38G/9.38G [01:13<00:00, 137MB/s]

# %%
# !unzip van-gogh-paintings.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/vangogh;

# %%
# !unzip food-101.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/;
# !rm food-101.zip;

# %%
# !rm -r /content/pytorch-CycleGAN-and-pix2pix/datasets/food-101/__MACOSX

# %%
# !kaggle datasets download -d soumikrakshit/anime-faces
# Out:
# ...
#  99% 436M/441M [00:03<00:00, 140MB/s]
# 100% 441M/441M [00:03<00:00, 120MB/s]

# %%
# !unzip sketch-rendered.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/sketch

# %%
# !unzip cat-and-dog.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/cat2dog

# %%
# !unzip anime-faces.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/anime

# %%
# !kaggle datasets download -d ashwingupta3012/human-faces
# Out:
# ...
#  99% 1.81G/1.82G [00:15<00:00, 149MB/s]
# 100% 1.82G/1.82G [00:15<00:00, 125MB/s]

# %%
# !unzip human-faces.zip -d /content/pytorch-CycleGAN-and-pix2pix/datasets/faces

# %%
os.getcwd()
# Out:
# '/content/pytorch-CycleGAN-and-pix2pix'

# %%
import shutil
from random import sample
def splitFiles(target, classes):
  [os.mkdir(os.path.join(target, name)) for name in ['trainA', 'trainB', 'testA','testB']]

  c = ('A', 'B')
  for i in range(len(classes)):
    ls = os.listdir(classes[i])
    for j in range(len(ls)):
      if j < len(ls)//10*9:
        shutil.move(os.path.join(classes[i],ls[j]), os.path.join(target, 'train'+c[i]+'/'+ls[j]))
      else:
        shutil.move(os.path.join(classes[i],ls[j]), os.path.join(target, 'test'+c[i]+'/'+ls[j]))

def move(target, source, exceptions):
  folders = os.listdir(source)
  for f in folders:
    if f not in exceptions:
      ls = os.listdir(os.path.join(source, f))
      for j in range(len(ls)):
        if j < len(ls)//10*9:
          shutil.move(os.path.join(source, f, ls[j]), os.path.join(target, 'trainA', ls[j]))
        else:
          shutil.move(os.path.join(source, f, ls[j]), os.path.join(target, 'testA', ls[j]))

def moveNum(target, source, num, let):
    ls = os.listdir(source)
    last = min(len(ls), num)
    ls = sample(ls, last)
    for j in range(last):
      file = os.path.join(source, ls[j])
      if os.path.isfile(file):
        if j < last//10*9:
          shutil.move(file, os.path.join(target, 'train'+let, ls[j]))
        else:
          shutil.move(file, os.path.join(target, 'test'+let, ls[j]))

# %%
splitFiles('datasets/cat2dog', ('datasets/cat2dog/training_set/training_set/cats', 'datasets/cat2dog/training_set/training_set/dogs'))

# %%
move('/content/pytorch-CycleGAN-and-pix2pix/datasets/anime2face','/content/pytorch-CycleGAN-and-pix2pix/datasets/anime',
     set())

# %%
moveNum('/content/pytorch-CycleGAN-and-pix2pix/datasets/anime2face','/content/pytorch-CycleGAN-and-pix2pix/datasets/faces/Humans',
     3000, 'A')

# %%
moveNum('/content/pytorch-CycleGAN-and-pix2pix/datasets/anime2face','/content/pytorch-CycleGAN-and-pix2pix/datasets/anime/data',
     3000, 'B')

# %%
moveNum('/content/pytorch-CycleGAN-and-pix2pix/datasets/sketch','/content/pytorch-CycleGAN-and-pix2pix/datasets/sketch-data/sketch-rendered/width-3',
     5000, 'A')

# %%
# !rm -r /content/pytorch-CycleGAN-and-pix2pix/datasets/anime2face/trainB
# !rm -r /content/pytorch-CycleGAN-and-pix2pix/datasets/anime2face/testB

# %%
try:
 os.mkdir('datasets/don2pan')
except:
   pass
splitFiles('datasets/don2pan', 
           ('/content/pytorch-CycleGAN-and-pix2pix/datasets/food-101/food-101/images/donuts',
            '/content/pytorch-CycleGAN-and-pix2pix/datasets/food-101/food-101/images/pancakes'))

# %%
source = '/content/pytorch-CycleGAN-and-pix2pix/datasets/vangogh'
target = '/content/pytorch-CycleGAN-and-pix2pix/datasets/van2photo'
folders = os.listdir(source)
ls = os.listdir(os.path.join(source, folders[1]))
os.listdir(os.path.join(source, folders[1]))
os.path.join(source, folders[1], ls[2])
shutil.move(os.path.join(source, folders[1], ls[2]), os.path.join(target, 'trainA', ls[2]))
# Out:
# '/content/pytorch-CycleGAN-and-pix2pix/datasets/van2photo/trainA/Lange Vijverberg, The Hague.jpg'

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, summer2winter_yosemite, horse2zebra, monet2photo, cezanne2photo, ukiyoe2photo, vangogh2photo, maps, cityscapes, facades, iphone2dslr_flower, ae_photos]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh ukiyoe2photo
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-09-27 20:08:41.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-07-14 09:14:47.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2014-04-16 21:43:55.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2014-11-04 16:16:25.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2016-12-02 18:27:55.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-01-09 02:00:22.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-01-08 02:44:01.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-07-23 10:15:26.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2015-05-12 05:30:12.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2016-03-21 11:07:42.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2016-02-07 10:10:02.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2014-06-07 19:37:03.jpg
#   inflating: ./datasets/ukiyoe2photo/trainB/2016-08-22 13:06:42.jpg
# ...

# %%
# Out:
# bash: cd: No such file or directory

# %%
print(os.getcwd())
print(len(os.listdir('datasets/apple2orange/testB')))
# Out:
# /content/pytorch-CycleGAN-and-pix2pix/pytorch-CycleGAN-and-pix2pix
# 248

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_cyclegan_model.sh style_ukiyoe
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [style_ukiyoe]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2022-04-30 04:01:40--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/style_ukiyoe.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/style_ukiyoe_pretrained/latest_net_G.pth’
#
# ./checkpoints/style 100%[===================>]  43.46M  10.5MB/s    in 6.7s
#
# ...

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !pip install wandb > /dev/null
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !wandb online
# Out:
# W&B online, running your script from this directory will now sync to the cloud.

# %%
# !python train.py --dataroot ./datasets/sketch --name sketch_uki --model cycle_gan --use_wandb
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/sketch             	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
# ...

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !cp /content/pytorch-CycleGAN-and-pix2pix/checkpoints/anime2face/latest_net_G_A.pth /content/pytorch-CycleGAN-and-pix2pix/checkpoints/face2anime/latest_net_G.pth

# %%
# !python test.py --dataroot datasets/summer2winter_yosemite/testA --name summer2winter_yosemite_pretrained --model test --no_dropout #--use_wandb

# %%
# !python test.py --dataroot datasets/anime2face/testB --name anime2face-pretrained --model test #--no_dropout #--use_wandb
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/anime2face/testB     	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: anime2face-pretrained         	[default: experiment_name]
#                       ndf: 64
# ...

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

path = './results/apple2orange_pretrained/test_latest/images/n07740461_12071'

img = plt.imread(path+'_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread(path+'_real.png')
plt.imshow(img)
